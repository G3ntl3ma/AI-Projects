# %%
"""
Klassifizierung der Appendix-Datensätze mit mehrschichtigem Netz 15x4x1 ohne Aktivierung
"""
import numpy as np
from infile import readfile

def scale(liste):
    #Eingabewerte anpassen
    for x in liste:
        x[0] = x[0] / 80; # Alter
        x[1] = x[1] - 0.9; # m/w                              
        x[11] = ( x[11]-36.0 )/4; #Temperatur
        x[12] = ( x[12]-36.0 )/4;
        x[13] = x[13]/24000.0; #Leukozyten
        
        for i in range(15):
            if x[i] ==0:
                x[i] = x[i] + 0.1


def output(vektor):
  #Berechnen des Ausgabewertes y

  y = 0 #Zurücksetzen
  inputs = np.zeros([15])
 
  # letzten Wert "abschneiden"  
  for i in range( 15 ):
      inputs[i] = vektor[i]
  
  # Eingabevektor mal Gewichtsmatrix = mittlere Schicht hL
  global hL
  hL = np.dot(inputs,wil)
    
  oL = [] #Output

  oL = np.dot(hL,wol)
  
  y = oL[0] 

  return y

def train():
    # Ein Durchlauf mit Fehlerrückführung
    #Zielwert
    t = x[15]
    
    #Anwenden der Delta_regel für die Outputschicht
    for i in range(4):
        delta = eta * hL[i] * ( t - y )
        wol[i] = wol[i] + delta

    
    
    #Berechnung des Fehlers
    error=t-y
    
    E=0
    for i in range(4):
        E=E+wol[i]
        
    #Aufteilung des Fehlers
    e=np.zeros([4])
    for i in range(4):
        e[i]=wol[i]/E*error
    
    #Gewichtsanpassung für die erste Schicht
    for j in range(4):
        for i in range(15):
            
            delta=eta*x[i]*e[j]
            
            wil[i][j]=delta+wil[i][j] 
    
            
"""
Hauptteil
"""

# Gewichtematrix InputLayer 15x4, Gewichte OutputLayer
# Füllen mit Zufallszahlen
wil=np.random.rand(15,4)-0.5
wol=np.random.rand(4,1) - 0.5

#print(wil)
#print(wol)

#Testdatei einlesen
testListe = readfile("App1.dat")
print( "Testdatei mit ", len(testListe)," Zeilen eingelesen" )

scale(testListe)

#Trainingsdatei einlesen
trainListe = readfile("App10.dat")
print( "Trainingsdatei mit ",len(trainListe)," Zeilen eingelesen" )

scale(trainListe)

#Lernrate
eta = 0.3; iterations =1 ;

print("\nTraining!\n")

for i in range(iterations):
    for x in trainListe:
        y = output(x) # y neu berechnen 
        
        # Trainieren des Netzes mit der Delta-Regel
        train()

#Netzausgabe berechnen

result=[]

for x in testListe:
    
    y=output(x)
    
    print(y)
     
    #Ergebnisliste
    result.append(round(y))

#Auswertung
r = 0
for i in range( len(testListe) ):
    if testListe[i][15]==result[i]:
       r = r+1 
    
print("\nRichtig: ",r, " das sind ", round( r/len(testListe) * 100), "%" )
# Out:
# Testdatei mit  1  Zeilen eingelesen
# Trainingsdatei mit  10  Zeilen eingelesen
#
# Training!
#
# 577.6917468006208
#
# Richtig:  0  das sind  0 %
